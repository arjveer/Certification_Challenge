# %% [markdown]
# # Using Ragas to Evaluate the RAG Application

# %% [markdown]
# ## Dependencies and API Keys:

# %%
#!pip install -qU ragas==0.2.10

# %%
#!pip install -qU langchain-community==0.3.14 langchain-openai==0.2.14 unstructured==0.16.12 langgraph==0.2.61 langchain-qdrant==0.2.0

# %% [markdown]
# We'll also need to provide our API keys.
#
# First, OpenAI's for our LLM/embedding model combination!

# %%
import os
from getpass import getpass
os.environ["OPENAI_API_KEY"] = getpass("Please enter your OpenAI API key!")

# %%
# Import the necessary Libraries
import json
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_openai.embeddings import OpenAIEmbeddings

# %% [markdown]
# ## Generating Synthetic Test Data
#
# We wil be using Ragas to build out a set of synthetic test questions, references, and reference contexts. This is useful because it will allow us to find out how our system is performing.

# %% [markdown]
# ### Data Preparation
#
# Let's start by collecting our data into a useful pile!

# %%
#Upload Dataset-10k.zip and unzip it dataset folder using -d option
# !unzip Dataset-10k.zip -d dataset

# %% [markdown]
# Next, let's load our data into a familiar LangChain format using the `DirectoryLoader`.

# %%
from langchain_community.document_loaders import DirectoryLoader

path = "data/"
loader = DirectoryLoader(path, glob="*.html")
docs = loader.load()

# %%
# Provide pdf_folder_location
pdf_folder_location = "data"
# Load the directory to pdf_loader
pdf_loader = PyPDFDirectoryLoader(pdf_folder_location)
docs = pdf_loader.load()

# %% [markdown]
# ### Knowledge Graph Based Synthetic Generation
#
# Ragas uses a knowledge graph based approach to create data. This is extremely useful as it allows us to create complex queries rather simply. The additional testset complexity allows us to evaluate larger problems more effectively, as systems tend to be very strong on simple evaluation tasks.
#
# Let's start by defining our `generator_llm` (which will generate our questions, summaries, and more), and our `generator_embeddings` which will be useful in building our graph.

# %% [markdown]
# ### Abstracted SDG
#
# The above method is the full process - but we can shortcut that using the provided abstractions!
#
# This will generate our knowledge graph under the hood, and will - from there - generate our personas and scenarios to construct our queries.

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=5)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/107 [00:00<?, ?it/s]
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29237, Requested 1721. Please try again in 1.916s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29044, Requested 1931. Please try again in 1.95s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29347, Requested 1745. Please try again in 2.184s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29232, Requested 1744. Please try again in 1.951s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29942, Requested 1850. Please try again in 3.584s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29181, Requested 1887. Please try again in 2.136s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29167, Requested 1773. Please try again in 1.879s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29238, Requested 1868. Please try again in 2.212s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29575, Requested 1802. Please try again in 2.754s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29551, Requested 1861. Please try again in 2.824s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Applying HeadlineSplitter:   0%|          | 0/135 [00:00<?, ?it/s]
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# Applying SummaryExtractor:   0%|          | 0/176 [00:00<?, ?it/s]
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29247, Requested 1742. Please try again in 1.978s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29507, Requested 1663. Please try again in 2.34s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29487, Requested 1743. Please try again in 2.46s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29244, Requested 1796. Please try again in 2.08s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29807, Requested 1627. Please try again in 2.868s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29686, Requested 1627. Please try again in 2.626s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '326b85'. Skipping!
# Property 'summary' already exists in node 'f8d7f9'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29562, Requested 1820. Please try again in 2.764s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node 'af42a5'. Skipping!
# Property 'summary' already exists in node '40e777'. Skipping!
# Property 'summary' already exists in node 'f38695'. Skipping!
# Property 'summary' already exists in node '7e90b1'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29800, Requested 1733. Please try again in 3.066s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '0dc75b'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29943, Requested 1740. Please try again in 3.366s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29888, Requested 1760. Please try again in 3.296s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '47d16f'. Skipping!
# Property 'summary' already exists in node '98061f'. Skipping!
# Property 'summary' already exists in node '0c930b'. Skipping!
# Property 'summary' already exists in node '765699'. Skipping!
# Property 'summary' already exists in node '4539f5'. Skipping!
# Property 'summary' already exists in node 'ece89e'. Skipping!
# Property 'summary' already exists in node '6d17c8'. Skipping!
# Property 'summary' already exists in node '1d2670'. Skipping!
# Property 'summary' already exists in node 'da6c84'. Skipping!
# Property 'summary' already exists in node 'de2832'. Skipping!
# Property 'summary' already exists in node '0d3190'. Skipping!
# Property 'summary' already exists in node '12b1e2'. Skipping!
# Property 'summary' already exists in node '71f658'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29200, Requested 1804. Please try again in 2.008s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node 'b4a1b5'. Skipping!
# Property 'summary' already exists in node '430d52'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29062, Requested 1564. Please try again in 1.252s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node 'ca1b77'. Skipping!
# Property 'summary' already exists in node 'b860bc'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29671, Requested 1668. Please try again in 2.678s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '79f6f1'. Skipping!
# Property 'summary' already exists in node 'f6dcb2'. Skipping!
# Property 'summary' already exists in node '61c4fe'. Skipping!
# Property 'summary' already exists in node '448500'. Skipping!
# Property 'summary' already exists in node 'd96e5b'. Skipping!
# Property 'summary' already exists in node 'aef2bb'. Skipping!
# Property 'summary' already exists in node '7abe5b'. Skipping!
# Property 'summary' already exists in node '057e50'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 28983, Requested 1723. Please try again in 1.412s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '747e96'. Skipping!
# Property 'summary' already exists in node 'f9f71a'. Skipping!
# Property 'summary' already exists in node '523c90'. Skipping!
# Property 'summary' already exists in node '2ec663'. Skipping!
# Property 'summary' already exists in node 'd61304'. Skipping!
# Property 'summary' already exists in node 'a524b6'. Skipping!
# Property 'summary' already exists in node '622894'. Skipping!
# Property 'summary' already exists in node '6d2a94'. Skipping!
# Property 'summary' already exists in node 'a88ecf'. Skipping!
# Property 'summary' already exists in node 'f6e9c8'. Skipping!
# Property 'summary' already exists in node '8d8471'. Skipping!
# Property 'summary' already exists in node 'fa30bd'. Skipping!
# Property 'summary' already exists in node 'cf69b9'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29306, Requested 1536. Please try again in 1.684s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node 'da3928'. Skipping!
# Property 'summary' already exists in node 'f586d0'. Skipping!
# Property 'summary' already exists in node '89f48f'. Skipping!
# Property 'summary' already exists in node '320b77'. Skipping!
# Property 'summary' already exists in node '061439'. Skipping!
# Property 'summary' already exists in node '206d49'. Skipping!
# Property 'summary' already exists in node 'f1c00a'. Skipping!
# Property 'summary' already exists in node '8bc856'. Skipping!
# Property 'summary' already exists in node '5d3102'. Skipping!
# Property 'summary' already exists in node '2b1019'. Skipping!
# Property 'summary' already exists in node '09320c'. Skipping!
# Property 'summary' already exists in node '4072df'. Skipping!
# Property 'summary' already exists in node 'ca8bc4'. Skipping!
# unable to apply transformation: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29759, Requested 1479. Please try again in 2.476s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Property 'summary' already exists in node '9a1e1d'. Skipping!
# Property 'summary' already exists in node 'dd114d'. Skipping!
# Property 'summary' already exists in node '5d8c7e'. Skipping!
# Property 'summary' already exists in node 'dd2f4c'. Skipping!
# Property 'summary' already exists in node '598a8e'. Skipping!
# Property 'summary' already exists in node '99bc75'. Skipping!
# Property 'summary' already exists in node '0b9368'. Skipping!
# Applying CustomNodeFilter:   0%|          | 0/60 [00:00<?, ?it/s]
# Node 7edd94b5-028c-4970-bfac-1a543071dc7b does not have a summary. Skipping filtering.
# Node 10673cec-02d9-47e2-a2ac-6bdc16e01adc does not have a summary. Skipping filtering.
# Node afc75a8d-1431-48ee-8f67-2047ee87c23e does not have a summary. Skipping filtering.
# Node 4f626d84-d51a-4386-ac40-53902a0778d6 does not have a summary. Skipping filtering.
# Node d86d7b15-8647-4213-ae2f-ffceb9a550fc does not have a summary. Skipping filtering.
# Node 8a451db6-d1b3-4ff3-bc33-cd3f6175f485 does not have a summary. Skipping filtering.
# Node fe311487-13d4-4681-89c9-1f0cd238001a does not have a summary. Skipping filtering.
# Node 5b979cd2-cccd-4bf1-b5c6-3e133e91a523 does not have a summary. Skipping filtering.
# Node 4e3802da-60eb-415a-8bbf-1e593e30ff1c does not have a summary. Skipping filtering.
# Node 43c7be9c-3041-439a-8799-e8b4c0b16a38 does not have a summary. Skipping filtering.
# Node 579f69c4-949f-4b65-9664-2afa48e0982c does not have a summary. Skipping filtering.
# Node 1f341758-cd32-4d48-8c9f-a7d38bac8c9b does not have a summary. Skipping filtering.
# Node 126d9069-df81-44f7-9121-d6b9e940b004 does not have a summary. Skipping filtering.
# Node 5b852be0-faaa-4a1e-8a38-2a8c4171b8c5 does not have a summary. Skipping filtering.
# Node b91f8fca-505a-4b34-8108-402500e63a6b does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/296 [00:00<?, ?it/s]
# Property 'summary_embedding' already exists in node '326b85'. Skipping!
# Property 'summary_embedding' already exists in node 'af42a5'. Skipping!
# Property 'summary_embedding' already exists in node 'f8d7f9'. Skipping!
# Property 'summary_embedding' already exists in node 'f64cee'. Skipping!
# Property 'summary_embedding' already exists in node '2884b6'. Skipping!
# Property 'summary_embedding' already exists in node '40e777'. Skipping!
# Property 'summary_embedding' already exists in node 'f38695'. Skipping!
# Property 'summary_embedding' already exists in node '0dc75b'. Skipping!
# Property 'summary_embedding' already exists in node '7e90b1'. Skipping!
# Property 'summary_embedding' already exists in node '47d16f'. Skipping!
# Property 'summary_embedding' already exists in node 'dd114d'. Skipping!
# Property 'summary_embedding' already exists in node '0d3190'. Skipping!
# Property 'summary_embedding' already exists in node 'da6c84'. Skipping!
# Property 'summary_embedding' already exists in node '98061f'. Skipping!
# Property 'summary_embedding' already exists in node '0c930b'. Skipping!
# Property 'summary_embedding' already exists in node '765699'. Skipping!
# Property 'summary_embedding' already exists in node 'ece89e'. Skipping!
# Property 'summary_embedding' already exists in node '1d2670'. Skipping!
# Property 'summary_embedding' already exists in node '4539f5'. Skipping!
# Property 'summary_embedding' already exists in node '6d17c8'. Skipping!
# Property 'summary_embedding' already exists in node 'de2832'. Skipping!
# Property 'summary_embedding' already exists in node '0b9368'. Skipping!
# Property 'summary_embedding' already exists in node 'ca8bc4'. Skipping!
# Property 'summary_embedding' already exists in node '8e444d'. Skipping!
# Property 'summary_embedding' already exists in node 'dd2f4c'. Skipping!
# Property 'summary_embedding' already exists in node '93e5fd'. Skipping!
# Property 'summary_embedding' already exists in node '12b1e2'. Skipping!
# Property 'summary_embedding' already exists in node '71f658'. Skipping!
# Property 'summary_embedding' already exists in node 'b4a1b5'. Skipping!
# Property 'summary_embedding' already exists in node '430d52'. Skipping!
# Property 'summary_embedding' already exists in node '79f6f1'. Skipping!
# Property 'summary_embedding' already exists in node 'ca1b77'. Skipping!
# Property 'summary_embedding' already exists in node 'b860bc'. Skipping!
# Property 'summary_embedding' already exists in node '2ec663'. Skipping!
# Property 'summary_embedding' already exists in node '61c4fe'. Skipping!
# Property 'summary_embedding' already exists in node 'f6dcb2'. Skipping!
# Property 'summary_embedding' already exists in node '448500'. Skipping!
# Property 'summary_embedding' already exists in node '598a8e'. Skipping!
# Property 'summary_embedding' already exists in node 'aef2bb'. Skipping!
# Property 'summary_embedding' already exists in node '89f48f'. Skipping!
# Property 'summary_embedding' already exists in node 'd96e5b'. Skipping!
# Property 'summary_embedding' already exists in node '7abe5b'. Skipping!
# Property 'summary_embedding' already exists in node '057e50'. Skipping!
# Property 'summary_embedding' already exists in node '99bc75'. Skipping!
# Property 'summary_embedding' already exists in node '523c90'. Skipping!
# Property 'summary_embedding' already exists in node '747e96'. Skipping!
# Property 'summary_embedding' already exists in node 'f9f71a'. Skipping!
# Property 'summary_embedding' already exists in node 'a524b6'. Skipping!
# Property 'summary_embedding' already exists in node 'd61304'. Skipping!
# Property 'summary_embedding' already exists in node '622894'. Skipping!
# Property 'summary_embedding' already exists in node 'f6e9c8'. Skipping!
# Property 'summary_embedding' already exists in node 'a88ecf'. Skipping!
# Property 'summary_embedding' already exists in node '6d2a94'. Skipping!
# Property 'summary_embedding' already exists in node '8d8471'. Skipping!
# Property 'summary_embedding' already exists in node 'fa30bd'. Skipping!
# Property 'summary_embedding' already exists in node 'cf69b9'. Skipping!
# Property 'summary_embedding' already exists in node '5d8c7e'. Skipping!
# Property 'summary_embedding' already exists in node '9a1e1d'. Skipping!
# Property 'summary_embedding' already exists in node 'da3928'. Skipping!
# Property 'summary_embedding' already exists in node '320b77'. Skipping!
# Property 'summary_embedding' already exists in node 'f586d0'. Skipping!
# Property 'summary_embedding' already exists in node '061439'. Skipping!
# Property 'summary_embedding' already exists in node '4072df'. Skipping!
# Property 'summary_embedding' already exists in node '206d49'. Skipping!
# Property 'summary_embedding' already exists in node 'f1c00a'. Skipping!
# Property 'summary_embedding' already exists in node '8bc856'. Skipping!
# Property 'summary_embedding' already exists in node '5d3102'. Skipping!
# Property 'summary_embedding' already exists in node '09320c'. Skipping!
# Property 'summary_embedding' already exists in node '2b1019'. Skipping!
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# unable to apply transformation: node.property('summary') must be a string, found '<class 'NoneType'>'
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# unable to apply transformation: Node 4f47a0c1-38a5-4f1d-952a-9aa237b937c3 has no summary_embedding
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  What is the significance of WASHINGTON, D.C. i...
# 1  me need know what Rule 405 is for, like why th...
# 2  what all them documents say about December 31,...
# 3  Wut is Note 1 and Note 5 about, and how do the...
# 4  How do the disclosures in Note 1 and Note 6 of...
# 5  what is Note 15 and Note 4 talk about in the a...
#
#                                   reference_contexts  \
# 0  [UNITED STATES SECURITIES AND EXCHANGE COMMISS...
# 1  [Indicate by check mark if the registrant is a...
# 2  [Documents incorporated by reference: Portions...
# 3  [<1-hop>\n\nAs of December 31, 2023 , our oper...
# 4  [<1-hop>\n\nDuring the years ended December 31...
# 5  [<1-hop>\n\nDuring the years ended December 31...
#
#                                            reference  \
# 0  WASHINGTON, D.C. is referenced as the location...
# 1  Rule 405 in this context is used to define if ...
# 2  Portions of IBM’s Annual Report to Stockholder...
# 3  Note 1 relates to accounting policies, includi...
# 4  Note 1 of the Notes to Consolidated Financial ...
# 5  Note 4 of the Notes to Consolidated Financial ...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  multi_hop_specific_query_synthesizer
# 4  multi_hop_specific_query_synthesizer
# 5  multi_hop_specific_query_synthesizer

# %% [markdown]
# ## LangChain RAG

# %% [markdown]
# ### R - Retrieval
#
# Let's start with building our retrieval pipeline, which will involve loading the same data we used to create our synthetic test set above.

# %%
path = "data/"
loader = DirectoryLoader(path, glob="*.html")
docs = loader.load()

# %%
# Provide pdf_folder_location
pdf_folder_location = "dataset"
# Load the directory to pdf_loader
pdf_loader = PyPDFDirectoryLoader(pdf_folder_location)
docs = pdf_loader.load()

# %% [markdown]
# Now that we have our data loaded, let's split it into chunks!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
split_documents = text_splitter.split_documents(docs)
len(split_documents)
# Out:
# 3657

# %% [markdown]
# Next up, we'll need to provide an embedding model that we can use to construct our vector store.

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# Now we can build our in memory QDrant vector store.

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

client = QdrantClient(":memory:")

client.create_collection(
    collection_name="10-k reports",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vector_store = QdrantVectorStore(
    client=client,
    collection_name="10-k reports",
    embedding=embeddings,
)

# %% [markdown]
# We can now add our documents to our vector store.

# %%
_ = vector_store.add_documents(documents=split_documents)

# %% [markdown]
# Let's define our retriever.

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 5})

# %% [markdown]
# Now we can produce a node for retrieval!

# %%
def retrieve(state):
  retrieved_docs = retriever.invoke(state["question"])
  return {"context" : retrieved_docs}

# %% [markdown]
# ### Augmented
#
# Let's create a simple RAG prompt!

# %%
from langchain.prompts import ChatPromptTemplate

RAG_PROMPT = """\
You are a helpful assistant who answers questions based on provided context. You must only use the provided context, and cannot use your own knowledge.

### Question
{question}

### Context
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_PROMPT)

# %% [markdown]
# ### Generation
#
# We'll also need an LLM to generate responses - we'll use `gpt-4o-mini` to avoid using the same model as our judge model.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# Then we can create a `generate` node!

# %%
def generate(state):
  docs_content = "\n\n".join(doc.page_content for doc in state["context"])
  messages = rag_prompt.format_messages(question=state["question"], context=docs_content)
  response = llm.invoke(messages)
  return {"response" : response.content}

# %% [markdown]
# ### Building RAG Graph with LangGraph
#
# Let's create some state for our LangGraph RAG graph!

# %%
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
from langchain_core.documents import Document

class State(TypedDict):
  question: str
  context: List[Document]
  response: str

# %% [markdown]
# Now we can build our simple graph!

# %%
graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %% [markdown]
# Let's do a test to make sure it's doing what we'd expect.

# %%
response = graph.invoke({"question" : "What are Microsoft investment in Azure"})

# %%
response["response"]
# Out:
# "Microsoft's investment in Azure encompasses several key areas:\n\n1. **Infrastructure and Platform Services**: Azure revenue is primarily driven by infrastructure-as-a-service and platform-as-a-service offerings, which are consumption-based, alongside per-user services like Enterprise Mobility + Security.\n\n2. **AI Capabilities**: Microsoft is focused on enhancing its AI offerings within Azure, providing customers with tools to optimize their businesses and adapt to challenges. This investment in AI aims to unlock value from digital expenditures and drive innovation.\n\n3. **Azure Virtual Desktop and Windows 365**: These services together achieved over $1 billion in annual revenue for the first time, reflecting significant investment and growth in cloud-based solutions.\n\n4. **Sustainability Investments**: Microsoft is investing in more efficient datacenters, clean energy, and sustainability initiatives. Through its Climate Innovation Fund, the company has allocated over $700 million to invest in sustainable solutions across various sectors.\n\n5. **Broader Microsoft Cloud Services**: Overall, Microsoft Cloud revenue increased by 22% to $111.6 billion, indicating robust investment in cloud services, including Azure and its associated products."

# %% [markdown]
# ## Evaluating the App with Ragas
#
# Now we can finally do our evaluation!
#
# We'll start by running the queries we generated usign SDG above through our application to get context and responses.

# %%
for test_row in dataset:
  response = graph.invoke({"question" : test_row.eval_sample.user_input})
  test_row.eval_sample.response = response["response"]
  test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

# %%
dataset.to_pandas()
# Out:
#                                           user_input  \
# 0  What is the significance of WASHINGTON, D.C. i...
# 1  me need know what Rule 405 is for, like why th...
# 2  what all them documents say about December 31,...
# 3  Wut is Note 1 and Note 5 about, and how do the...
# 4  How do the disclosures in Note 1 and Note 6 of...
# 5  what is Note 15 and Note 4 talk about in the a...
#
#                                   retrieved_contexts  \
# 0  [UNITED STATES\nSECURITIES AND EXCHANGE COMMIS...
# 1  [4. The registrant’s other certifying officer(...
# 2  [Item 6. [Reserved]\nItem 7. Management’s Disc...
# 3  [reference.\nThe instruments defining the righ...
# 4  [the Notes to Consolidated Financial Statement...
# 5  [For additional information about each line it...
#
#                                   reference_contexts  \
# 0  [UNITED STATES SECURITIES AND EXCHANGE COMMISS...
# 1  [Indicate by check mark if the registrant is a...
# 2  [Documents incorporated by reference: Portions...
# 3  [<1-hop>\n\nAs of December 31, 2023 , our oper...
# 4  [<1-hop>\n\nDuring the years ended December 31...
# 5  [<1-hop>\n\nDuring the years ended December 31...
#
#                                             response  \
# 0  The significance of WASHINGTON, D.C. in the co...
# 1  The context provided does not explicitly menti...
# 2  The documents mention December 31, 2023, in th...
# 3  Note 1 and Note 5 discuss aspects related to l...
# 4  The disclosures in Note 1 and Note 6 of the No...
# 5  Note 4 and Note 15 in the annual report relate...
#
#                                            reference  \
# 0  WASHINGTON, D.C. is referenced as the location...
# 1  Rule 405 in this context is used to define if ...
# 2  Portions of IBM’s Annual Report to Stockholder...
# 3  Note 1 relates to accounting policies, includi...
# 4  Note 1 of the Notes to Consolidated Financial ...
# 5  Note 4 of the Notes to Consolidated Financial ...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  multi_hop_specific_query_synthesizer
# 4  multi_hop_specific_query_synthesizer
# 5  multi_hop_specific_query_synthesizer

# %% [markdown]
# Then we can convert that table into a `EvaluationDataset` which will make the process of evaluation smoother.

# %%
from ragas import EvaluationDataset

evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())

# %% [markdown]
# We'll need to select a judge model - in this case we're using the same model that was used to generate our Synthetic Data.

# %%
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper

evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1"))

# %% [markdown]
# Next up - we simply evaluate on our desired metrics!

# %%
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import evaluate, RunConfig

custom_run_config = RunConfig(timeout=360)

result = evaluate(
    dataset=evaluation_dataset,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
    llm=evaluator_llm,
    run_config=custom_run_config
)
result
# Out:
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Exception raised in Job[29]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29208, Requested 1839. Please try again in 2.094s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[11]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29670, Requested 1669. Please try again in 2.678s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[7]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29363, Requested 2138. Please try again in 3.002s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[13]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 29237, Requested 2188. Please try again in 2.85s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[31]: RateLimitError(Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4.1 in organization org-raBMZk0ComSs6jAO0zww7ARn on tokens per min (TPM): Limit 30000, Used 28622, Requested 1783. Please try again in 810ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}})
# Exception raised in Job[17]: TimeoutError()
# {'context_recall': 0.2778, 'faithfulness': 0.3958, 'factual_correctness': 0.3083, 'answer_relevancy': 0.6308, 'context_entity_recall': 0.1656, 'noise_sensitivity_relevant': 0.0370}
